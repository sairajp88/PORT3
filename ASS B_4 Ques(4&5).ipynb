# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some Number')
plt.xlabel('any data')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'go')
plt.plot([1,2,3,4],[1,4,9,16],'g--')
plt.show()

# %%
#Line plot

# %%
#bar Plot

# %%
import matplotlib.pyplot as plt
names=['a','b','c']
values=[1,10,100]
plt.subplot(141)
plt.bar(names,values)
plt.subplot(142)
plt.scatter(names,values)
plt.subplot(143)
plt.plot(names,values,linewidth=5.0)
plt.subplot(144)
plt.plot(names,values,'--')
plt.show()

# %%
#pie plot

# %%
import matplotlib.pyplot as plt
cars=['AUDI','BMW','FORD','TESLA','JAGUR','MERCEDES']
data=[23,17,35,29,12,41]
fig=plt.figure(figsize=(10,7))
plt.pie(data,labels=cars)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
pstore = pd.read_csv("/Users/prathamesh/Desktop/Dsbda/Data sets/dataset_Facebook.csv")
pstore.head(10)
sns.distplot(pstore.like)

plt.style.use("dark_background")

sns.pairplot(pstore[['like', 'share', 'comment','Total Interactions']])
plt.show()
# Out:
# /var/folders/kx/cfn79n_51s77smhxdhq3ndfw0000gn/T/ipykernel_6206/1140004848.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(pstore.like)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
print(p_store.head())
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
# 9            139441   Photo         3          12             6         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# ...

# %%
print(pstore.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(pstore.head())
#
# NameError: name 'pstore' is not defined
